# %%
# %pylab inline
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train_data = pd.read_csv('../data/scaled_test.csv', index_col='PassengerId')

# %%
style="ticks", color_codes=True
sns.pairplot(train_data, vars=["Age", "male", "female"], hue="Survived")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7b55b99b5f35> in <module>()
# ----> 1 sns.pairplot(train_data,vars=["Age", "male", "female"], hue="Survived")
#
# /opt/local/anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1607     if grid.square_grid:
#    1608         if diag_kind == "hist":
# -> 1609             grid.map_diag(plt.hist, **diag_kws)
#    1610         elif diag_kind == "kde":
#    1611             diag_kws["legend"] = False
#
# /opt/local/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_diag(self, func, **kwargs)
#    1346                 else:
#    1347                     func(vals, color=self.palette, histtype="barstacked",
# -> 1348                          **kwargs)
# ...
