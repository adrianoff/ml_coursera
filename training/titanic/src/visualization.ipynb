# %%
# %pylab inline
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train_data = pd.read_csv('../data/scaled_train.csv', index_col='PassengerId')
train_data.head()
# Out:
#                   Age      Fare  Parch  SibSp  female  male  Pclass1  \
# PassengerId
# 1           -0.584223 -0.503255      0      1       0     1        0
# 2            0.628019  0.734765      0      1       1     0        1
# 3           -0.281163 -0.490205      0      0       1     0        0
# 4            0.400723  0.383209      0      1       1     0        1
# 5            0.400723 -0.487788      0      0       0     1        0
#
#              Pclass1.1  Pclass3  Embarked_C  Embarked_Q  Embarked_S  Survived
# PassengerId
# 1                    0        1           0           0           1         0
# 2                    0        0           1           0           0         1
# 3                    0        1           0           0           1         1
# 4                    0        0           0           0           1         1
# 5                    0        1           0           0           1         0

# %%
#sns.pairplot(train_data[['Age', 'Fare', 'Survived', 'male', 'female']], hue="Survived")

# %%
train_data.Fare = np.log(train_data.Fare.values)
#np.log([12, -2])
# Out:
# /opt/local/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
